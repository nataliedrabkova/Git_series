# %%
# This ismy first file and my first commit

print("I love Git")

# This is a change to my code:

print("I love merging and branching")
